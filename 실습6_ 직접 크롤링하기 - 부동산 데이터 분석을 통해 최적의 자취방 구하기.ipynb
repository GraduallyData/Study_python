# %% [markdown]
# # **부동산 데이터: 최적의 자취방 구하기**

# %% [markdown]
# ## **크롤링**

# %%
# !pip install user-agent
# Out:
# Requirement already satisfied: user-agent in c:\users\82105\appdata\local\programs\python\python39\lib\site-packages (0.1.10)
# Requirement already satisfied: six in c:\users\82105\appdata\roaming\python\python39\site-packages (from user-agent) (1.15.0)

# %%
from user_agent import generate_user_agent, generate_navigator
user_agent = generate_user_agent()
user_agent
# Out:
# 'Mozilla/5.0 (X11; Ubuntu; Linux i686 on x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'

# %%
import requests
import numpy as np
import pandas as pd

# %%
from tqdm.notebook import tqdm
import time

# %%
article_list = []
for i in tqdm(range(1, 101)):
    try:
        url = f'https://m.land.naver.com/cluster/ajax/articleList?itemId=&mapKey=&lgeo=&showR0=&rletTpCd=OPST%3AVL%3AOR&tradTpCd=B2&z=12&lat=37.481021&lon=126.951601&btm=37.3398975&lft=126.6762562&top=37.6218785&rgt=127.2269458&totCnt=8360&cortarNo=1162000000&sort=rank&page={i}'

        user_agent = generate_user_agent()
        headers = {'User-Agent':user_agent}

        res = requests.get(url, headers=headers)
        time.sleep(1)

        article_json = res.json()
        article_body = article_json['body']
        article_list.append(article_body)
    except:
        break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
article_list1 = [j for i in article_list for j in i]

# %%
data = pd.DataFrame(article_list1)

# %%
data = data[['atclNo','rletTpNm','flrInfo','rentPrc','hanPrc','spc1','spc2','direction','atclCfmYmd','repImgUrl','lat','lng','atclFetrDesc','tagList']]
data.columns = ['물건번호','구분','층수(물건층/전체층)','월세','보증금','계약면적(m2)','전용면적(m2)','방향','확인일자','이미지','위도','경도','설명','태그']
data
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세       보증금 계약면적(m2) 전용면적(m2)   방향  \
# 0     2427207185  원룸         3/5   50     1,000       26       20  남동향
# 1     2427231637  원룸         3/4   53       500       26       20  남동향
# 2     2427152976  원룸         3/5   35     1,000       19     19.8  남동향
# 3     2427259114  원룸       10/12   60     1,000       21       21   북향
# 4     2427136854  원룸         4/6   35       500       19     19.8  남동향
# ...          ...  ..         ...  ...       ...      ...      ...  ...
# 1835  2426983421  원룸         1/3   40       500       29     19.8  남서향
# 1836  2426983313  원룸         4/5   60     5,000       33     23.1   동향
# 1837  2427003002  원룸         3/4   10  1억 2,000       26    19.83  남서향
# 1838  2426984319  빌라         4/5  120     8,000       48    29.94  남동향
# 1839  2427001509  원룸         1/3   45     9,000       28    21.48  남서향
#
#            확인일자                                                이미지         위도  \
# 0     24.06.04.  /20240604_67/land_naver_1717492861456YbM8A_JPE...  37.482606
# 1     24.06.04.  /20240604_274/land_naver_17174928655341y6NP_JP...  37.483719
# 2     24.06.04.  /20240605_12/land_naver_1717563001123sCjbD_JPE...  37.478232
# 3     24.06.04.  /20240604_105/land_naver_1717492921755HEtTS_JP...  37.485445
# 4     24.06.04.  /20240605_207/land_naver_1717563121118pKvfB_JP...  37.478903
# ...         ...                                                ...        ...
# 1835  24.06.03.  /20240603_50/land_naver_1717374637661gRVEg_JPE...  37.477409
# 1836  24.06.03.  /20240603_101/land_naver_1717374580606WAMwk_JP...  37.473339
# 1837  24.06.03.  /20240603_143/land_naver_1717391377179SA8Ww_JP...  37.484701
# 1838  24.06.03.  /20240603_221/land_naver_1717393906793JbNGF_JP...  37.468638
# 1839  24.06.03.  /20240603_55/land_naver_1717391251310nmw3l_JPE...  37.481772
#
#               경도                            설명                   태그
# 0     126.932851          신림역 도보6분.엘베O.큰방. 베란다     [25년이내, 마당, 역세권]
# 1     126.933617     신림역 5분.신축급분리형.지구대 바로앞 안전.     [10년이내, 마당, 역세권]
# 2     126.961926       2호선 역세권 대로변 주택가 가성비 풀옵션  [25년이내, 융자금적은, 역세권]
# 3     126.931018      신림역원룸 보증금대출가능 올리모데링 착한원룸  [10년이내, 융자금적은, 역세권]
# 4     126.960305       2호선 역세권 대로변가 조용한 주택 풀옵션  [25년이내, 융자금적은, 역세권]
# ...          ...                           ...                  ...
# 1835  126.966583          풀옵션 혼자살기 딱 좋은 가성비 원룸  [25년이내, 융자금적은, 역세권]
# 1836  126.963713       너무 이쁜 복층 신축급 컨디션 올 화이트톤   [4년이내, 융자금적은, 역세권]
# 1837  126.912192             깔끔하고, 혼자 살기 좋은 방.  [10년이내, 융자금적은, 역세권]
# 1838  126.939284  역세권 초품아의 우아하고 예쁘며 풀옵션에 신축 투룸  [2년이내, 융자금적은, 소형평수]
# 1839  126.923269             1.5룸식 혼자 살기 좋은 방.    [4년이내, 융자금적은, 1층]
#
# [1840 rows x 14 columns]

# %%
data.to_excel('C:/Users/82105/Desktop/csv파일/data.xlsx')

# %% [markdown]
# ## **질문 만들기**

# %% [markdown]
# - 최적의 자취방 구하기
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %% [markdown]
# ## **데이터 전처리**

# %%
import plotly.express as px
import folium

import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_excel('C:/Users/82105/Desktop/csv파일/data.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0        물건번호  구분 층수(물건층/전체층)  월세    보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0           0  2427207185  원룸         3/5  50  1,000       26      20.0  남동향
# 1           1  2427231637  원룸         3/4  53    500       26      20.0  남동향
# 2           2  2427152976  원룸         3/5  35  1,000       19      19.8  남동향
# 3           3  2427259114  원룸       10/12  60  1,000       21      21.0   북향
# 4           4  2427136854  원룸         4/6  35    500       19      19.8  남동향
#
#         확인일자                                                이미지         위도  \
# 0  24.06.04.  /20240604_67/land_naver_1717492861456YbM8A_JPE...  37.482606
# 1  24.06.04.  /20240604_274/land_naver_17174928655341y6NP_JP...  37.483719
# 2  24.06.04.  /20240605_12/land_naver_1717563001123sCjbD_JPE...  37.478232
# 3  24.06.04.  /20240604_105/land_naver_1717492921755HEtTS_JP...  37.485445
# 4  24.06.04.  /20240605_207/land_naver_1717563121118pKvfB_JP...  37.478903
#
#            경도                         설명                         태그
# 0  126.932851       신림역 도보6분.엘베O.큰방. 베란다     ['25년이내', '마당', '역세권']
# 1  126.933617  신림역 5분.신축급분리형.지구대 바로앞 안전.     ['10년이내', '마당', '역세권']
# 2  126.961926    2호선 역세권 대로변 주택가 가성비 풀옵션  ['25년이내', '융자금적은', '역세권']
# 3  126.931018   신림역원룸 보증금대출가능 올리모데링 착한원룸  ['10년이내', '융자금적은', '역세권']
# 4  126.960305    2호선 역세권 대로변가 조용한 주택 풀옵션  ['25년이내', '융자금적은', '역세권']

# %%
data = data.iloc[:,1:]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1840 entries, 0 to 1839
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   물건번호         1840 non-null   int64
#  1   구분           1840 non-null   object
#  2   층수(물건층/전체층)  1840 non-null   object
#  3   월세           1840 non-null   int64
#  4   보증금          1840 non-null   object
#  5   계약면적(m2)     1840 non-null   object
#  6   전용면적(m2)     1840 non-null   float64
#  7   방향           1840 non-null   object
#  8   확인일자         1840 non-null   object
#  9   이미지          1671 non-null   object
#  10  위도           1840 non-null   float64
#  11  경도           1840 non-null   float64
#  12  설명           1718 non-null   object
#  13  태그           1840 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 201.4+ KB

# %% [markdown]
# - 월세 0원인 경우 제외

# %%
data = data.query('월세 > 0')

# %% [markdown]
# - 보증금 숫자로 변환

# %%
data['보증금'].unique()
# Out:
# array(['1,000', '500', '3,000', '100', '200', '300', '5,000', '7,000',
#        '4,000', '2,000', '1억 1,000', '20', '1억', '400', '4,500', '5,500',
#        '3억 5,500', '2억 3,000', '50', '70', '1억 5,000', '1억 4,800',
#        '2억 8,000', '1억 8,000', '1억 9,500', '1억 7,000', '1억 1,600',
#        '1억 4,700', '2억', '1억 2,000', '6,000', '1억 5,200', '2억 7,000',
#        '90', '8,000', '9,400', '1억 3,000', '1,500', '8,200', '75', '30',
#        '3억', '8,500', '1억 6,000', '1억 2,800', '1억 2,500', '60', '650',
#        '9,830', '3억 2,000', '2억 4,900', '3,500', '6,800', '1억 9,000',
#        '3,400', '9,000', '600', '700', '2억 2,500', '1억 4,000', '2억 4,696',
#        '1억 8,700', '3,900', '3억 5,000', '2억 4,000', '2억 1,000', '2,500',
#        '9,600', '4억 2,000', '2억 1,600', '150', '3억 8,000', '3억 6,000',
#        '7,500', '3억 3,000', '1억 4,600', '1억 800'], dtype=object)

# %%
data = data.query('~보증금.str.contains("억")')

# %%
data['보증금'].unique()
# Out:
# array(['1,000', '500', '3,000', '100', '200', '300', '5,000', '7,000',
#        '4,000', '2,000', '20', '400', '4,500', '5,500', '50', '70',
#        '6,000', '90', '8,000', '9,400', '1,500', '8,200', '75', '30',
#        '8,500', '60', '650', '9,830', '3,500', '6,800', '3,400', '9,000',
#        '600', '700', '3,900', '2,500', '9,600', '150', '7,500'],
#       dtype=object)

# %%
data['보증금'] = data['보증금'].str.replace(',','').astype(int)
data['보증금'].unique()
# Out:
# array([1000,  500, 3000,  100,  200,  300, 5000, 7000, 4000, 2000,   20,
#         400, 4500, 5500,   50,   70, 6000,   90, 8000, 9400, 1500, 8200,
#          75,   30, 8500,   60,  650, 9830, 3500, 6800, 3400, 9000,  600,
#         700, 3900, 2500, 9600,  150, 7500])

# %% [markdown]
# - 물건층과 전체층 분리 후 1층과 꼭대기층 유무 컬럼 만들기
#     - 지하의 경우 마이너스로 표시

# %%
data[['물건층','전체층']] = data['층수(물건층/전체층)'].str.split('/', expand=True)

# %%
data.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0  2427207185  원룸         3/5  50  1000       26      20.0  남동향  24.06.04.
# 1  2427231637  원룸         3/4  53   500       26      20.0  남동향  24.06.04.
# 2  2427152976  원룸         3/5  35  1000       19      19.8  남동향  24.06.04.
# 3  2427259114  원룸       10/12  60  1000       21      21.0   북향  24.06.04.
# 4  2427136854  원룸         4/6  35   500       19      19.8  남동향  24.06.04.
#
#                                                  이미지         위도          경도  \
# 0  /20240604_67/land_naver_1717492861456YbM8A_JPE...  37.482606  126.932851
# 1  /20240604_274/land_naver_17174928655341y6NP_JP...  37.483719  126.933617
# 2  /20240605_12/land_naver_1717563001123sCjbD_JPE...  37.478232  126.961926
# 3  /20240604_105/land_naver_1717492921755HEtTS_JP...  37.485445  126.931018
# 4  /20240605_207/land_naver_1717563121118pKvfB_JP...  37.478903  126.960305
#
#                           설명                         태그 물건층 전체층
# 0       신림역 도보6분.엘베O.큰방. 베란다     ['25년이내', '마당', '역세권']   3   5
# 1  신림역 5분.신축급분리형.지구대 바로앞 안전.     ['10년이내', '마당', '역세권']   3   4
# 2    2호선 역세권 대로변 주택가 가성비 풀옵션  ['25년이내', '융자금적은', '역세권']   3   5
# 3   신림역원룸 보증금대출가능 올리모데링 착한원룸  ['10년이내', '융자금적은', '역세권']  10  12
# 4    2호선 역세권 대로변가 조용한 주택 풀옵션  ['25년이내', '융자금적은', '역세권']   4   6

# %%
data['물건층'].unique()
# Out:
# array(['3', '10', '4', '7', 'B1', '저', '2', '5', '6', '8', '고', '1', '중',
#        '9', '11', '17', '12', '14', '15', '26', '13'], dtype=object)

# %%
def floor_info(target, total):
    try:
        if target in ['B1','B2']: #지하이면
            return 'y'
        elif int(target) == 1 or int(target)/int(total) == 1: #1층이거나 꼭대기층이면
            return 'y'
        else:
            return 'n'
    except ValueError:
        return 'n'

# %%
data['비선호층여부'] = data.apply(lambda x: floor_info(x['물건층'], x['전체층']), axis=1)

# %%
data.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0  2427207185  원룸         3/5  50  1000       26      20.0  남동향  24.06.04.
# 1  2427231637  원룸         3/4  53   500       26      20.0  남동향  24.06.04.
# 2  2427152976  원룸         3/5  35  1000       19      19.8  남동향  24.06.04.
# 3  2427259114  원룸       10/12  60  1000       21      21.0   북향  24.06.04.
# 4  2427136854  원룸         4/6  35   500       19      19.8  남동향  24.06.04.
#
#                                                  이미지         위도          경도  \
# 0  /20240604_67/land_naver_1717492861456YbM8A_JPE...  37.482606  126.932851
# 1  /20240604_274/land_naver_17174928655341y6NP_JP...  37.483719  126.933617
# 2  /20240605_12/land_naver_1717563001123sCjbD_JPE...  37.478232  126.961926
# 3  /20240604_105/land_naver_1717492921755HEtTS_JP...  37.485445  126.931018
# 4  /20240605_207/land_naver_1717563121118pKvfB_JP...  37.478903  126.960305
#
#                           설명                         태그 물건층 전체층 비선호층여부
# 0       신림역 도보6분.엘베O.큰방. 베란다     ['25년이내', '마당', '역세권']   3   5      n
# 1  신림역 5분.신축급분리형.지구대 바로앞 안전.     ['10년이내', '마당', '역세권']   3   4      n
# 2    2호선 역세권 대로변 주택가 가성비 풀옵션  ['25년이내', '융자금적은', '역세권']   3   5      n
# 3   신림역원룸 보증금대출가능 올리모데링 착한원룸  ['10년이내', '융자금적은', '역세권']  10  12      n
# 4    2호선 역세권 대로변가 조용한 주택 풀옵션  ['25년이내', '융자금적은', '역세권']   4   6      n

# %% [markdown]
# - 제외 조건에 해당하는 매물 제외
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %%
#보증금 3000만원 이하
#지하, 반지하, 꼭대기층은 선호하지 않음
#북향은 선호하지 않음
data_filtered = data.query('300 <= 보증금 <= 3000 and 비선호층여부 == "n" and 전체층 != "1" and ~방향.str.contains("북")')

# %%
data_filtered
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세   보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0     2427207185  원룸         3/5   50  1000       26     20.00  남동향
# 1     2427231637  원룸         3/4   53   500       26     20.00  남동향
# 2     2427152976  원룸         3/5   35  1000       19     19.80  남동향
# 4     2427136854  원룸         4/6   35   500       19     19.80  남동향
# 5     2427206284  원룸         3/4   53  3000       28     23.00  남동향
# ...          ...  ..         ...  ...   ...      ...       ...  ...
# 1807  2427070350  빌라         4/6  140  3000       35     29.91  남서향
# 1824  2426983681  빌라         고/9   75  3000       38     26.97  남동향
# 1829  2426983952  빌라         중/3   90  2000       48     43.32  남동향
# 1831  2426985138  원룸         저/8   45  3000       23     19.83  남동향
# 1834  2426999858  원룸         6/7   25  2500        -     19.80  남동향
#
#            확인일자                                                이미지         위도  \
# 0     24.06.04.  /20240604_67/land_naver_1717492861456YbM8A_JPE...  37.482606
# 1     24.06.04.  /20240604_274/land_naver_17174928655341y6NP_JP...  37.483719
# 2     24.06.04.  /20240605_12/land_naver_1717563001123sCjbD_JPE...  37.478232
# 4     24.06.04.  /20240605_207/land_naver_1717563121118pKvfB_JP...  37.478903
# 5     24.06.04.  /20240604_136/land_naver_1717492802313U5AFz_JP...  37.483719
# ...         ...                                                ...        ...
# 1807  24.06.03.  /20240603_123/land_naver_1717395743742H7m92_JP...  37.471363
# 1824  24.06.03.  /20240603_89/land_naver_1717390106943OrLKA_JPE...  37.481106
# 1829  24.06.03.  /20240603_199/land_naver_1717390187916SpFfd_JP...  37.480186
# 1831  24.06.03.  /20240603_271/land_naver_1717390267480HTAok_JP...  37.486530
# 1834  24.06.03.  /20240603_168/land_naver_1717376608445Nzz4k_JP...  37.484990
#
#               경도                                       설명  \
# 0     126.932851                     신림역 도보6분.엘베O.큰방. 베란다
# 1     126.933617                신림역 5분.신축급분리형.지구대 바로앞 안전.
# 2     126.961926                  2호선 역세권 대로변 주택가 가성비 풀옵션
# 4     126.960305                  2호선 역세권 대로변가 조용한 주택 풀옵션
# 5     126.933617  신림역 5분. 분리형. 크기 짱. 지구대 바로 앞 안전. 여성분 강추.
# ...          ...                                      ...
# 1807  126.922121                                      NaN
# 1824  126.946069              안전한집 봉천역 깔끔하고 구조좋은 1.5룸입니다.
# 1829  126.942200                   안전한집봉천역 역세권 깔끔한 투룸입니다.
# 1831  126.927067                안전한집 신림역 깔끔하고 구조좋은 원룸입니다.
# 1834  126.909506               창문에서 바라본 초저녁 야경이 이렇게 아름다워요
#
#                              태그 물건층 전체층 비선호층여부
# 0        ['25년이내', '마당', '역세권']   3   5      n
# 1        ['10년이내', '마당', '역세권']   3   4      n
# 2     ['25년이내', '융자금적은', '역세권']   3   5      n
# 4     ['25년이내', '융자금적은', '역세권']   4   6      n
# 5        ['10년이내', '마당', '역세권']   3   4      n
# ...                         ...  ..  ..    ...
# 1807  ['2년이내', '화장실한개', '소형평수']   4   6      n
# 1824  ['10년이내', '융자금적은', '역세권']   고   9      n
# 1829  ['25년이상', '융자금적은', '역세권']   중   3      n
# 1831  ['10년이내', '융자금적은', '역세권']   저   8      n
# 1834  ['15년이내', '융자금적은', '역세권']   6   7      n
#
# [716 rows x 17 columns]

# %% [markdown]
# - 태그 컬럼 분리

# %%
data_filtered[['tag1','tag2','tag3','tag4']] = data_filtered['태그'].str.replace("\'|\[|\]","").str.split(', ', expand=True)

# %%
data_filtered.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0  2427207185  원룸         3/5  50  1000       26      20.0  남동향  24.06.04.
# 1  2427231637  원룸         3/4  53   500       26      20.0  남동향  24.06.04.
# 2  2427152976  원룸         3/5  35  1000       19      19.8  남동향  24.06.04.
# 4  2427136854  원룸         4/6  35   500       19      19.8  남동향  24.06.04.
# 5  2427206284  원룸         3/4  53  3000       28      23.0  남동향  24.06.04.
#
#                                                  이미지  ...          경도  \
# 0  /20240604_67/land_naver_1717492861456YbM8A_JPE...  ...  126.932851
# 1  /20240604_274/land_naver_17174928655341y6NP_JP...  ...  126.933617
# 2  /20240605_12/land_naver_1717563001123sCjbD_JPE...  ...  126.961926
# 4  /20240605_207/land_naver_1717563121118pKvfB_JP...  ...  126.960305
# 5  /20240604_136/land_naver_1717492802313U5AFz_JP...  ...  126.933617
#
#                                         설명                         태그 물건층 전체층  \
# 0                     신림역 도보6분.엘베O.큰방. 베란다     ['25년이내', '마당', '역세권']   3   5
# 1                신림역 5분.신축급분리형.지구대 바로앞 안전.     ['10년이내', '마당', '역세권']   3   4
# 2                  2호선 역세권 대로변 주택가 가성비 풀옵션  ['25년이내', '융자금적은', '역세권']   3   5
# 4                  2호선 역세권 대로변가 조용한 주택 풀옵션  ['25년이내', '융자금적은', '역세권']   4   6
# 5  신림역 5분. 분리형. 크기 짱. 지구대 바로 앞 안전. 여성분 강추.     ['10년이내', '마당', '역세권']   3   4
#
#   비선호층여부      tag1     tag2    tag3  tag4
# 0      n  ['25년이내'     '마당'  '역세권']  None
# 1      n  ['10년이내'     '마당'  '역세권']  None
# 2      n  ['25년이내'  '융자금적은'  '역세권']  None
# 4      n  ['25년이내'  '융자금적은'  '역세권']  None
# 5      n  ['10년이내'     '마당'  '역세권']  None
#
# [5 rows x 21 columns]

# %% [markdown]
# - 연식 컬럼 추가

# %%
data_filtered = data_filtered.query('tag1.str.contains("년")') #연식 정보가 있는 데이터만 필터링

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 1834
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   물건번호         716 non-null    int64
#  1   구분           716 non-null    object
#  2   층수(물건층/전체층)  716 non-null    object
#  3   월세           716 non-null    int64
#  4   보증금          716 non-null    int32
#  5   계약면적(m2)     716 non-null    object
#  6   전용면적(m2)     716 non-null    float64
#  7   방향           716 non-null    object
#  8   확인일자         716 non-null    object
#  9   이미지          647 non-null    object
#  10  위도           716 non-null    float64
#  11  경도           716 non-null    float64
#  12  설명           673 non-null    object
#  13  태그           716 non-null    object
#  14  물건층          716 non-null    object
#  15  전체층          716 non-null    object
#  16  비선호층여부       716 non-null    object
#  17  tag1         716 non-null    object
#  18  tag2         716 non-null    object
#  19  tag3         716 non-null    object
#  20  tag4         69 non-null     object
# dtypes: float64(3), int32(1), int64(2), object(15)
# memory usage: 120.3+ KB

# %%
data_filtered['연식'] = [int(i[0]) for i in data_filtered['tag1'].str.split('년')]
data_filtered
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data_filtered['연식'] = [int(i[0]) for i in data_filtered['tag1'].str.split('년')]
#       2 data_filtered
#
# Cell In[39], line 1, in <listcomp>(.0)
# ----> 1 data_filtered['연식'] = [int(i[0]) for i in data_filtered['tag1'].str.split('년')]
#       2 data_filtered
#
# ValueError: invalid literal for int() with base 10: "['25"

# %%
import re

data_filtered['연식'] = [int(re.findall('\d+', i[0])[0]) if re.findall('\d+', i[0]) else None for i in data_filtered['tag1'].str.split('년')]
data_filtered
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세   보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0     2427207185  원룸         3/5   50  1000       26     20.00  남동향
# 1     2427231637  원룸         3/4   53   500       26     20.00  남동향
# 2     2427152976  원룸         3/5   35  1000       19     19.80  남동향
# 4     2427136854  원룸         4/6   35   500       19     19.80  남동향
# 5     2427206284  원룸         3/4   53  3000       28     23.00  남동향
# ...          ...  ..         ...  ...   ...      ...       ...  ...
# 1807  2427070350  빌라         4/6  140  3000       35     29.91  남서향
# 1824  2426983681  빌라         고/9   75  3000       38     26.97  남동향
# 1829  2426983952  빌라         중/3   90  2000       48     43.32  남동향
# 1831  2426985138  원룸         저/8   45  3000       23     19.83  남동향
# 1834  2426999858  원룸         6/7   25  2500        -     19.80  남동향
#
#            확인일자                                                이미지  ...  \
# 0     24.06.04.  /20240604_67/land_naver_1717492861456YbM8A_JPE...  ...
# 1     24.06.04.  /20240604_274/land_naver_17174928655341y6NP_JP...  ...
# 2     24.06.04.  /20240605_12/land_naver_1717563001123sCjbD_JPE...  ...
# 4     24.06.04.  /20240605_207/land_naver_1717563121118pKvfB_JP...  ...
# 5     24.06.04.  /20240604_136/land_naver_1717492802313U5AFz_JP...  ...
# ...         ...                                                ...  ...
# 1807  24.06.03.  /20240603_123/land_naver_1717395743742H7m92_JP...  ...
# 1824  24.06.03.  /20240603_89/land_naver_1717390106943OrLKA_JPE...  ...
# 1829  24.06.03.  /20240603_199/land_naver_1717390187916SpFfd_JP...  ...
# 1831  24.06.03.  /20240603_271/land_naver_1717390267480HTAok_JP...  ...
# 1834  24.06.03.  /20240603_168/land_naver_1717376608445Nzz4k_JP...  ...
#
#                                            설명                         태그 물건층  \
# 0                        신림역 도보6분.엘베O.큰방. 베란다     ['25년이내', '마당', '역세권']   3
# 1                   신림역 5분.신축급분리형.지구대 바로앞 안전.     ['10년이내', '마당', '역세권']   3
# 2                     2호선 역세권 대로변 주택가 가성비 풀옵션  ['25년이내', '융자금적은', '역세권']   3
# 4                     2호선 역세권 대로변가 조용한 주택 풀옵션  ['25년이내', '융자금적은', '역세권']   4
# 5     신림역 5분. 분리형. 크기 짱. 지구대 바로 앞 안전. 여성분 강추.     ['10년이내', '마당', '역세권']   3
# ...                                       ...                        ...  ..
# 1807                                      NaN  ['2년이내', '화장실한개', '소형평수']   4
# 1824              안전한집 봉천역 깔끔하고 구조좋은 1.5룸입니다.  ['10년이내', '융자금적은', '역세권']   고
# 1829                   안전한집봉천역 역세권 깔끔한 투룸입니다.  ['25년이상', '융자금적은', '역세권']   중
# 1831                안전한집 신림역 깔끔하고 구조좋은 원룸입니다.  ['10년이내', '융자금적은', '역세권']   저
# 1834               창문에서 바라본 초저녁 야경이 이렇게 아름다워요  ['15년이내', '융자금적은', '역세권']   6
#
#      전체층 비선호층여부      tag1     tag2     tag3  tag4  연식
# 0      5      n  ['25년이내'     '마당'   '역세권']  None  25
# 1      4      n  ['10년이내'     '마당'   '역세권']  None  10
# 2      5      n  ['25년이내'  '융자금적은'   '역세권']  None  25
# 4      6      n  ['25년이내'  '융자금적은'   '역세권']  None  25
# 5      4      n  ['10년이내'     '마당'   '역세권']  None  10
# ...   ..    ...       ...      ...      ...   ...  ..
# 1807   6      n   ['2년이내'  '화장실한개'  '소형평수']  None   2
# 1824   9      n  ['10년이내'  '융자금적은'   '역세권']  None  10
# 1829   3      n  ['25년이상'  '융자금적은'   '역세권']  None  25
# 1831   8      n  ['10년이내'  '융자금적은'   '역세권']  None  10
# 1834   7      n  ['15년이내'  '융자금적은'   '역세권']  None  15
#
# [716 rows x 22 columns]

# %% [markdown]
# - 필요한 컬럼만 남기기

# %%
data_filtered.columns
# Out:
# Index(['물건번호', '구분', '층수(물건층/전체층)', '월세', '보증금', '계약면적(m2)', '전용면적(m2)', '방향',
#        '확인일자', '이미지', '위도', '경도', '설명', '태그', '물건층', '전체층', '비선호층여부', 'tag1',
#        'tag2', 'tag3', 'tag4', '연식'],
#       dtype='object')

# %%
data_filtered = data_filtered[['물건번호','월세','보증금','전용면적(m2)','방향','위도','경도','물건층','전체층','연식']]
data_filtered.head()
# Out:
#          물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식
# 0  2427207185  50  1000      20.0  남동향  37.482606  126.932851   3   5  25
# 1  2427231637  53   500      20.0  남동향  37.483719  126.933617   3   4  10
# 2  2427152976  35  1000      19.8  남동향  37.478232  126.961926   3   5  25
# 4  2427136854  35   500      19.8  남동향  37.478903  126.960305   4   6  25
# 5  2427206284  53  3000      23.0  남동향  37.483719  126.933617   3   4  10

# %% [markdown]
# - 위도, 경도를 이용하여 역까지의 거리 재기

# %%
coordinate = pd.read_csv('C:/Users/82105/Desktop/csv파일/서울시 역사마스터 정보.csv', encoding='cp949')
coordinate = coordinate.query('호선 == "2호선"')
station_list = ['신대방', '신림', '봉천', '서울대입구(관악구청)', '낙성대', '사당']
coordinate.query('역사명 in @station_list')
# Out:
#      역사_ID          역사명   호선         위도          경도
# 727    231          신대방  2호선  37.487462  126.913149
# 728    230           신림  2호선  37.484201  126.929715
# 729    229           봉천  2호선  37.482362  126.941892
# 730    228  서울대입구(관악구청)  2호선  37.481247  126.952739
# 731    227          낙성대  2호선  37.476930  126.963693
# 732    226           사당  2호선  37.476538  126.981544

# %%
#위경도 거리 재는 라이브러리
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\82105\appdata\local\programs\python\python39\lib\site-packages (2.8.1)

# %%
from haversine import haversine

haversine((37.487462,126.913149), (37.484201,126.929715), unit = 'm')
# Out:
# 1505.9854014218404

# %%
def distance(station_name, lat, long):
    station_lat = coordinate.query(f'역사명 == "{station_name}"')['위도'].values[0]
    station_long = coordinate.query(f'역사명 == "{station_name}"')['경도'].values[0]

    distance = haversine((station_lat, station_long), (lat, long), unit = 'm')

    return distance

# %%
for s in station_list:
    data_filtered[s] = data_filtered.apply(lambda x: distance(s, x['위도'], x['경도']), axis=1)

# %%
data_filtered.head()
# Out:
#          물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0  2427207185  50  1000      20.0  남동향  37.482606  126.932851   3   5  25
# 1  2427231637  53   500      20.0  남동향  37.483719  126.933617   3   4  10
# 2  2427152976  35  1000      19.8  남동향  37.478232  126.961926   3   5  25
# 4  2427136854  35   500      19.8  남동향  37.478903  126.960305   4   6  25
# 5  2427206284  53  3000      23.0  남동향  37.483719  126.933617   3   4  10
#
#            신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0  1820.327675   328.669444   798.218086  1761.378282  2793.750566
# 1  1853.312197   348.443246   745.589637  1709.524112  2759.190798
# 2  4424.627115  2918.739319  1826.481121   877.256770   212.774695
# 4  4268.352413  2762.763807  1669.665400   716.701295   370.826955
# 5  1853.312197   348.443246   745.589637  1709.524112  2759.190798
#
#             사당
# 0  4349.379926
# 1  4303.821563
# 2  1741.382516
# 4  1892.559220
# 5  4303.821563

# %%
data_filtered['역까지최소거리'] = data_filtered.apply(lambda x: min([x['신대방'], x['신림'], x['봉천'], x['서울대입구(관악구청)'], x['낙성대'], x['사당']]), axis=1)
data_filtered.head()
# Out:
#          물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0  2427207185  50  1000      20.0  남동향  37.482606  126.932851   3   5  25
# 1  2427231637  53   500      20.0  남동향  37.483719  126.933617   3   4  10
# 2  2427152976  35  1000      19.8  남동향  37.478232  126.961926   3   5  25
# 4  2427136854  35   500      19.8  남동향  37.478903  126.960305   4   6  25
# 5  2427206284  53  3000      23.0  남동향  37.483719  126.933617   3   4  10
#
#            신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0  1820.327675   328.669444   798.218086  1761.378282  2793.750566
# 1  1853.312197   348.443246   745.589637  1709.524112  2759.190798
# 2  4424.627115  2918.739319  1826.481121   877.256770   212.774695
# 4  4268.352413  2762.763807  1669.665400   716.701295   370.826955
# 5  1853.312197   348.443246   745.589637  1709.524112  2759.190798
#
#             사당     역까지최소거리
# 0  4349.379926  328.669444
# 1  4303.821563  348.443246
# 2  1741.382516  212.774695
# 4  1892.559220  370.826955
# 5  4303.821563  348.443246

# %%
data_filtered.drop(station_list, axis=1, inplace=True)
data_filtered.head()
# Out:
#          물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0  2427207185  50  1000      20.0  남동향  37.482606  126.932851   3   5  25
# 1  2427231637  53   500      20.0  남동향  37.483719  126.933617   3   4  10
# 2  2427152976  35  1000      19.8  남동향  37.478232  126.961926   3   5  25
# 4  2427136854  35   500      19.8  남동향  37.478903  126.960305   4   6  25
# 5  2427206284  53  3000      23.0  남동향  37.483719  126.933617   3   4  10
#
#       역까지최소거리
# 0  328.669444
# 1  348.443246
# 2  212.774695
# 4  370.826955
# 5  348.443246

# %% [markdown]
# ## **분석**

# %% [markdown]
# - 각 항목 분포 확인하기

# %%
for x in ['월세','보증금','전용면적(m2)','연식','역까지최소거리']:
    fig = px.box(data_frame = data_filtered, x=x, width=700, height=400)
    fig.show()

# %% [markdown]
# - 내가 원하는 조건은?
#     - 보증금 3000만원 이하 ✅
#     - 월세는 저렴할수록 좋음
#     - 지하, 반지하, 꼭대기층은 선호하지 않음 ✅
#     - 전용면적이 클수록 좋음
#     - 북향은 선호하지 않음 ✅
#     - 연식이 오래되지 않을수록 좋음
#     - 지하철 역에서 가까울수록 좋음

# %% [markdown]
# - 월세, 전용면적, 연식, 지하철역까지의 거리 점수 매기기

# %%
data_filtered
# Out:
#             물건번호   월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     2427207185   50  1000     20.00  남동향  37.482606  126.932851   3   5  25
# 1     2427231637   53   500     20.00  남동향  37.483719  126.933617   3   4  10
# 2     2427152976   35  1000     19.80  남동향  37.478232  126.961926   3   5  25
# 4     2427136854   35   500     19.80  남동향  37.478903  126.960305   4   6  25
# 5     2427206284   53  3000     23.00  남동향  37.483719  126.933617   3   4  10
# ...          ...  ...   ...       ...  ...        ...         ...  ..  ..  ..
# 1807  2427070350  140  3000     29.91  남서향  37.471363  126.922121   4   6   2
# 1824  2426983681   75  3000     26.97  남동향  37.481106  126.946069   고   9  10
# 1829  2426983952   90  2000     43.32  남동향  37.480186  126.942200   중   3  25
# 1831  2426985138   45  3000     19.83  남동향  37.486530  126.927067   저   8  10
# 1834  2426999858   25  2500     19.80  남동향  37.484990  126.909506   6   7  15
#
#           역까지최소거리
# 0      328.669444
# 1      348.443246
# 2      212.774695
# 4      370.826955
# 5      348.443246
# ...           ...
# 1807  1576.984436
# 1824   394.145753
# 1829   243.482043
# 1831   348.793462
# 1834   422.936769
#
# [716 rows x 11 columns]

# %%
data_filtered['월세_등급'] = pd.qcut(data_filtered['월세'], 5, labels=[1,2,3,4,5])
data_filtered['전용면적_등급'] = pd.qcut(data_filtered['전용면적(m2)'], 5, labels=[5,4,3,2,1])
data_filtered['연식_등급'] = pd.qcut(data_filtered['연식'].rank(method='first'), 5, labels=[1,2,3,4,5])
data_filtered['역까지최소거리_등급'] = pd.qcut(data_filtered['역까지최소거리'], 5, labels=[1,2,3,4,5])

# %%
data_filtered
# Out:
#             물건번호   월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     2427207185   50  1000     20.00  남동향  37.482606  126.932851   3   5  25
# 1     2427231637   53   500     20.00  남동향  37.483719  126.933617   3   4  10
# 2     2427152976   35  1000     19.80  남동향  37.478232  126.961926   3   5  25
# 4     2427136854   35   500     19.80  남동향  37.478903  126.960305   4   6  25
# 5     2427206284   53  3000     23.00  남동향  37.483719  126.933617   3   4  10
# ...          ...  ...   ...       ...  ...        ...         ...  ..  ..  ..
# 1807  2427070350  140  3000     29.91  남서향  37.471363  126.922121   4   6   2
# 1824  2426983681   75  3000     26.97  남동향  37.481106  126.946069   고   9  10
# 1829  2426983952   90  2000     43.32  남동향  37.480186  126.942200   중   3  25
# 1831  2426985138   45  3000     19.83  남동향  37.486530  126.927067   저   8  10
# 1834  2426999858   25  2500     19.80  남동향  37.484990  126.909506   6   7  15
#
#           역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 0      328.669444     3       3     3          2
# 1      348.443246     4       3     1          2
# 2      212.774695     1       4     3          1
# 4      370.826955     1       4     3          3
# 5      348.443246     4       2     1          2
# ...           ...   ...     ...   ...        ...
# 1807  1576.984436     5       1     1          5
# 1824   394.145753     5       1     3          3
# 1829   243.482043     5       1     5          1
# 1831   348.793462     2       3     3          2
# 1834   422.936769     1       4     3          3
#
# [716 rows x 15 columns]

# %%
data_filtered_final = data_filtered.query('월세_등급 <= 3 and 전용면적_등급 <= 1 and 연식_등급 <= 2 and 역까지최소거리_등급 <= 2')
data_filtered_final
# Out:
#             물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 42    2426948486  50  3000     16.50   서향  37.478414  126.965482   2   4  10
# 98    2426579602  42   500     23.10  남동향  37.485926  126.915701   저   4  10
# 105   2426371974  48  3000     20.10   남향  37.479818  126.940503   3   4   4
# 157   2425885854  50  1000     19.80  남서향  37.475648  126.963922   저   3  10
# 167   2425963643  48  1000     19.80   동향  37.482572  126.952236   2   5  10
# 205   2425905246  48  1000     19.80  남서향  37.482572  126.952236   2   5  10
# 368   2425047754  50  2000     23.10  남서향  37.484695  126.911671   2   4   4
# 583   2425712353  30  1000     19.83   동향  37.478821  126.961485   저   4   4
# 644   2427642955  50  3000     19.80   남향  37.481089  126.945215   5   8  10
# 647   2427638613  48  3000     18.20  남서향  37.485031  126.926015   2   7  10
# 659   2427644576  35  2000     19.80   동향  37.482002  126.955747   2   4  10
# 725   2427663125  39   500     19.84  남동향  37.485926  126.915701   저   4  10
# 815   2427679470  40   500     21.49  남동향  37.484695  126.911671   저   4   4
# 989   2427472524  39   500     19.84  남서향  37.478612  126.954048   저   3  10
# 991   2427475169  50  2000     23.10   남향  37.482225  126.955961   중   3  10
# 992   2427463682  35  3000     18.10   서향  37.480344  126.944394   2   8  10
# 994   2427469550  40  3000     19.80   남향  37.481106  126.945038   5   8  10
# 1015  2427442479  15  3000     21.92  남동향  37.486893  126.927902   2  10  10
# 1121  2425549377  45  3000     20.16   남향  37.480344  126.944394   3   8  10
# 1194  2427479360  50  1000     19.80  남동향  37.477352  126.964591   3   7  10
# 1198  2427472955  50  1000     19.80  남서향  37.479694  126.940717   2   4  10
# 1230  2427430964  50  3000     17.00  남동향  37.479977  126.944294   3   9   2
# 1257  2427421669  50  2000     16.52  남동향  37.483131  126.927913   2  12  10
# 1320  2427357483  25  2000     23.14  남동향  37.485873  126.928528   7  10  10
# 1322  2427362222  45   500     19.83  남서향  37.475100  126.978586   저   3  10
# 1326  2427360531  30  1000     13.22   서향  37.481871  126.954634   5   6  10
# 1334  2427368724  50  2000     20.00  남동향  37.482284  126.954478   5  10  10
# 1393  2427233617  50  1000     23.14  남동향  37.480386  126.942200   2   5  10
# 1396  2427241197  50  2000     19.80   남향  37.484160  126.940765   3   4  10
# 1422  2427197888  42   500     19.84  남동향  37.486320  126.927699   3   8   2
# 1426  2427198613  35   300     19.84  남동향  37.486165  126.928542   4   5  10
# 1436  2427194850  35   300     19.84  남동향  37.485561  126.927178   5   8  10
# 1444  2427171301  45  2000     23.10   동향  37.481898  126.955219   저   3  10
# 1445  2427168348  50  1000     23.10   동향  37.482572  126.952236   2   5  10
# 1453  2427168919  50  2000     19.80   남향  37.483205  126.938402   2   4  10
# 1515  2426976167  40   300     23.14  남동향  37.481832  126.927094   2   3  10
# 1543  2427240714  43  1000     21.48   남향  37.487125  126.915423   중   5  10
# 1552  2427216587  45  1000     21.48   남향  37.487353  126.915562   중   3  10
# 1582  2426985707  50  1000     19.84  남동향  37.478171  126.953761   3   5  10
# 1601  2425482132  37  2000     19.80   남향  37.484035  126.944910   저   3  10
#
#          역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 42    228.367165     3       5     1          1
# 98    282.617445     2       2     1          2
# 105   308.290922     3       3     1          2
# 157   143.977313     3       4     1          1
# 167   153.873600     3       4     1          1
# 205   153.873600     3       4     1          1
# 368   334.172884     3       2     1          2
# 583   286.664212     1       3     1          2
# 644   325.596164     3       4     2          2
# 647   339.264675     3       4     2          2
# 659   278.382504     1       4     2          2
# 725   282.617445     1       3     2          2
# 815   334.172884     1       2     1          2
# 989   314.944945     1       3     2          2
# 991   304.393545     3       2     2          2
# 992   314.790068     1       4     2          2
# 994   310.750930     1       4     2          2
# 1015  339.400363     1       2     2          2
# 1121  314.790068     2       3     2          2
# 1194   92.094306     3       4     2          1
# 1198  314.264210     3       4     2          2
# 1230  339.491166     3       5     1          2
# 1257  198.588786     3       5     2          1
# 1320  213.389064     1       2     2          1
# 1322  306.111701     2       3     2          2
# 1326  181.036985     1       5     2          1
# 1334  191.943101     3       3     2          1
# 1393  221.395914     3       2     2          1
# 1396  223.294387     3       4     2          1
# 1422  295.227697     2       3     1          2
# 1426  241.671258     1       3     2          1
# 1436  270.145749     1       3     2          2
# 1444  230.494068     2       2     2          1
# 1445  153.873600     3       2     2          1
# 1453  321.898808     3       4     2          2
# 1515  350.537005     1       2     2          2
# 1543  204.108895     2       2     2          1
# 1552  213.248201     2       2     2          1
# 1582  353.725190     3       3     2          2
# 1601  324.841437     1       4     2          2

# %% [markdown]
# - 최종 매물 리스트 시각화

# %%
f = folium.Figure(width=700, height=500)
m = folium.Map(location=[37.486313, 126.935378], zoom_start=14).add_to(f)

for idx in data_filtered_final.index:
    lat = data_filtered_final.loc[idx, '위도']
    long = data_filtered_final.loc[idx, '경도']
    num = data_filtered_final.loc[idx, '물건번호']

    folium.Marker([lat, long]
                  , popup=f"<a href=https://m.land.naver.com/article/info/{num}>링크</a>"
                  ).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9eb8f7168617fc6bdd31854cbac53df9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9eb8f7168617fc6bdd31854cbac53df9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9eb8f7168617fc6bdd31854cbac53df9 = L.map(
#                 &quot;map_9eb8f7168617fc6bdd31854cbac53df9&quot;,
#                 {
#                     center: [37.486313, 126.935378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86ddcd0fee5cdf9d86147cd0478e1461 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#             var marker_df1ba780e56cee718da59350efb3815d = L.marker(
#                 [37.478414, 126.965482],
#                 {}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#         var popup_fa3f24ccb9bf31446ec6e3f6bc52aae0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2228ae1108acd1cd4577db0001f4d49 = $(`&lt;div id=&quot;html_c2228ae1108acd1cd4577db0001f4d49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2426948486&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_fa3f24ccb9bf31446ec6e3f6bc52aae0.setContent(html_c2228ae1108acd1cd4577db0001f4d49);
#
#
#
#         marker_df1ba780e56cee718da59350efb3815d.bindPopup(popup_fa3f24ccb9bf31446ec6e3f6bc52aae0)
#         ;
#
#
#
#
#             var marker_c6d342b4382ccdb9edb271485a02279b = L.marker(
#                 [37.485926, 126.915701],
#                 {}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#         var popup_8b58c6bb1681f1efc8e95e0035a70b1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66c26862605c5eb48337247324a2864a = $(`&lt;div id=&quot;html_66c26862605c5eb48337247324a2864a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2426579602&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_8b58c6bb1681f1efc8e95e0035a70b1d.setContent(html_66c26862605c5eb48337247324a2864a);
#
#
#
#         marker_c6d342b4382ccdb9edb271485a02279b.bindPopup(popup_8b58c6bb1681f1efc8e95e0035a70b1d)
#         ;
#
#
#
#
#             var marker_db18a6095e572f1fc9eb4e65eb3b47b0 = L.marker(
#                 [37.479818, 126.940503],
#                 {}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#         var popup_f22add21a832c8499c6932924be2a281 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fb044e432352b415ad16fa09a07dc89 = $(`&lt;div id=&quot;html_1fb044e432352b415ad16fa09a07dc89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2426371974&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_f22add21a832c8499c6932924be2a281.setContent(html_1fb044e432352b415ad16fa09a07dc89);
#
#
#
#         marker_db18a6095e572f1fc9eb4e65eb3b47b0.bindPopup(popup_f22add21a832c8499c6932924be2a281)
#         ;
#
#
#
#
#             var marker_329e3e5d6bcbb0de5937ea5f047d3cff = L.marker(
#                 [37.475648, 126.963922],
#                 {}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#         var popup_2f26c2faee490ed1471a6bc82111d7da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_353af72f3ad94ebfc9ff8ce38d4686a9 = $(`&lt;div id=&quot;html_353af72f3ad94ebfc9ff8ce38d4686a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2425885854&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_2f26c2faee490ed1471a6bc82111d7da.setContent(html_353af72f3ad94ebfc9ff8ce38d4686a9);
#
#
#
#         marker_329e3e5d6bcbb0de5937ea5f047d3cff.bindPopup(popup_2f26c2faee490ed1471a6bc82111d7da)
#         ;
#
#
#
#
#             var marker_b04935590cec3b9d2429d0189a955872 = L.marker(
#                 [37.482572, 126.952236],
#                 {}
#             ).addTo(map_9eb8f7168617fc6bdd31854cbac53df9);
#
#
#         var popup_9d765087deb5fc578e14837cc1e342ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1c7c10d92b6c1ae39e1b35f16f79175 = $(`&lt;div id=&quot;html_c1c7c10d92b6c1ae39e1b35f16f79175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2425963643&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_9d765087deb5fc578e14837cc1e342ef.setContent(html_c1c7c10d92b6c1ae39e1b35f16f79175);
#
#
#
#         marker_b04935590cec3b9d2429d0189a955872.bindPopup(popup_9d765087deb5fc578e14837cc1e342ef)
#         ;
